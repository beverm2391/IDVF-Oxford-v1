# %%
import pandas as pd
import numpy as np

# %%
result = pd.read_csv("/Users/beneverman/Documents/Coding/QuantHive/IDVF-Oxford-v1/outputs/linear-as-close-as-possible-v2/2023-10-16_20-12-20/result.csv", index_col=0)

# %%
result.tail(5)
# Out:
#                               TMOout     ABTout      HDout     MCDout  \
# datetime
# 2023-10-09 10:35:00-04:00  -9.952368 -10.441736 -10.602368 -10.139485
# 2023-10-09 11:40:00-04:00 -10.855933 -11.033193 -10.565236 -10.473813
# 2023-10-09 12:45:00-04:00 -10.665588 -11.486452 -11.438974 -11.696479
# 2023-10-09 13:50:00-04:00 -11.492610 -11.537959 -11.437435 -11.868337
# 2023-10-09 14:55:00-04:00 -11.868052 -11.575974 -11.708767 -11.848885
#
#                                PGout     CATout     DISout     CCIout  \
# datetime
# 2023-10-09 10:35:00-04:00 -10.369773  -9.486224 -10.008078  -9.524521
# 2023-10-09 11:40:00-04:00 -10.697884  -9.924288 -10.186864  -9.999536
# 2023-10-09 12:45:00-04:00 -11.512169 -10.811629 -10.940563 -10.967525
# 2023-10-09 13:50:00-04:00 -11.944693 -10.830351 -11.045856 -10.653404
# 2023-10-09 14:55:00-04:00 -11.685718 -10.986129 -11.170442 -10.959626
#
#                               JNJout      KOout  ...   COSTreal    IBMreal  \
# ...
