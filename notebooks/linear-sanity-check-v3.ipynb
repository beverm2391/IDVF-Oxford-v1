# %%
import pandas as pd

from lib.utils import get_65min_aggs

# %%
data = pd.read_csv('/Users/beneverman/Documents/Coding/QuantHive/IDVF-Oxford-v1/data/processed-5yr-93-minute/65min_rv.csv', index_col=0)

# %%
data2 = get_65min_aggs()

# %%
data
# Out:
#                        datetime        TMO        ABT         HD        MCD  \
# 0     2018-10-11 10:35:00-04:00  -9.302132  -9.308770  -8.861162  -9.032787
# 1     2018-10-11 11:40:00-04:00  -9.226515  -9.660382  -9.765163 -10.027525
# 2     2018-10-11 12:45:00-04:00  -9.818327 -10.029960 -10.518059 -10.743978
# 3     2018-10-11 13:50:00-04:00 -10.207846 -10.672297 -10.974280 -11.049742
# 4     2018-10-11 14:55:00-04:00  -8.921766  -8.968561  -8.872568  -9.690731
# ...                         ...        ...        ...        ...        ...
# 7511  2023-10-09 11:40:00-04:00 -10.733918 -11.561414 -11.459266 -11.630080
# 7512  2023-10-09 12:45:00-04:00 -11.575774 -11.660044 -11.389878 -11.992928
# 7513  2023-10-09 13:50:00-04:00 -11.869460 -11.628670 -11.684992 -11.961455
# 7514  2023-10-09 14:55:00-04:00 -11.277812 -11.982515 -11.641741 -12.104332
# 7515  2023-10-09 16:00:00-04:00 -11.655459 -11.975486 -11.603576 -11.875128
#
# ...

# %%
data2
# Out:
#                        datetime       TMO      ABT       HD      MCD       PG  \
# 0     2018-10-11 09:30:00-04:00  231.4025  68.9400  195.260  165.720   80.680
# 1     2018-10-11 10:35:00-04:00  228.4800  68.6200  193.320  164.405   80.185
# 2     2018-10-11 11:40:00-04:00  231.4800  69.3857  194.630  164.970   79.970
# 3     2018-10-11 12:45:00-04:00  228.9800  68.8200  193.570  164.150   79.660
# 4     2018-10-11 13:50:00-04:00  226.8900  68.3500  190.040  162.850   79.210
# ...                         ...       ...      ...      ...      ...      ...
# 7511  2023-10-09 10:35:00-04:00  492.3400  96.0800  291.235  248.350  141.960
# 7512  2023-10-09 11:40:00-04:00  492.7300  95.8850  292.350  247.935  142.340
# 7513  2023-10-09 12:45:00-04:00  494.6027  96.4200  294.245  249.410  142.935
# 7514  2023-10-09 13:50:00-04:00  497.1050  96.7100  295.300  249.300  143.010
# 7515  2023-10-09 14:55:00-04:00  496.0900  96.7600  295.360  249.950  143.360
#
# ...

# %%
result = pd.read_csv("/Users/beneverman/Documents/Coding/QuantHive/IDVF-Oxford-v1/outputs/linear-as-close-as-possible-v2/2023-10-16_20-12-20/result.csv", index_col=0)
report = pd.read_csv("/Users/beneverman/Documents/Coding/QuantHive/IDVF-Oxford-v1/outputs/linear-as-close-as-possible-v2/2023-10-16_20-12-20/report.csv", index_col=0)

# %%
report.describe()
# Out:
#              MSE   r2_score       MAPE
# count  93.000000  93.000000  93.000000
# mean    0.253814   0.698717   0.035898
# std     0.023867   0.022873   0.002408
# min     0.188770   0.640770   0.030049
# 25%     0.242645   0.680533   0.034555
# 50%     0.253372   0.700198   0.035682
# 75%     0.269451   0.714535   0.037332
# max     0.310789   0.745395   0.042423
